# %% [markdown]
# # Welcome to Colab!

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/gmvani/
#   inflating: data/gmvani/01-00159-02.mp3
#   inflating: data/gt.txt
#    creating: data/lahaja/
#   inflating: data/lahaja/audio.wav
#   inflating: data/w5Jyq3XMbb3WwiKQ.wav

# %%
import os
from google.colab import userdata
from huggingface_hub import login

# Retrieve token securely from Secrets
os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# !pip install onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 73.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -q onnxruntime-gpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 MB 6.1 MB/s eta 0:00:00

# %%
pip install --force-reinstall onnxruntime-gpu --extra-index-url https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/onnxruntime-cuda-12/pypi/simple/
# Out:
# Looking in indexes: https://pypi.org/simple, https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/onnxruntime-cuda-12/pypi/simple/
# ...
#   Using cached onnxruntime_gpu-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# ...
# Using cached onnxruntime_gpu-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl (246.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.2/343.2 kB 33.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.0/130.0 kB 14.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.12.19
#     Uninstalling flatbuffers-25.12.19:
#       Successfully uninstalled flatbuffers-25.12.19
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
#   Attempting uninstall: packaging
# ...

# %%
# !python3 indicconfor.py \
  --data-dir data \
  --ground-truth data/gt.txt \
  --evaluate \
  --batch-size 1 \
  --evaluation-output indicconfor_evaluation.json
# Out:
# Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 404 files:   0% 0/404 [00:00<?, ?it/s]
#
# Fetching 404 files:  35% 143/404 [00:00<00:00, 1426.81it/s]
#
# Fetching 404 files: 100% 404/404 [00:00<00:00, 1604.75it/s]
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B                         Please check FRAME_DURATION_MS. The timestamps can be inaccurate
# ...

# %%
# !pip install -q --upgrade --force-reinstall \
    "numpy==2.2.6" \
    "numba>=0.67.0" \
    "librosa>=0.11.0" \
    "transformers>=5.13.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 82.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 103.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 104.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.4/846.4 kB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.1/306.1 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip install "numpy<2.3"

# %%
# !python transcriber_nemotron.py \
    --data-dir data \
    --evaluate \
    --language hi-IN \
    --ground-truth data/gt.txt \
    --evaluation-output evaluation_results_nemotron.json
# Out:
# ...
# Loading NVIDIA Nemotron 3.5 ASR
# ...
# Model              : nvidia/nemotron-3.5-asr-streaming-0.6b
# Device             : cuda
# Language           : hi-IN
# Lookahead tokens   : 6
# Max new tokens     : 8192
#
# Loading processor...
# Loading model...
#
# Model sampling rate: 16000 Hz
# Streaming latency   : 560 ms
#
# Streaming first chunk samples: 7880
# Streaming chunk samples: 9360
# Streaming first mel frames: 49
# Streaming mel frames/chunk: 56
#
# Model loaded successfully.
# ...
#
#
# ...
# EVALUATION SLICE: clean
# ...
#
# [clean] data/gmvani/01-00159-02.mp3
#   duration: 9.51 sec
#   hypothesis: खुलने वाले उन सरकार या बाकी का समर्थक होते हैं आम नगरीज नहीं, इसलिए उनको लाभ नहीं मिल पाता है।  धन्यवाद
#   RTF: 0.2728
#
# [clean] data/lahaja/audio.wav
#   duration: 11.64 sec
#   hypothesis: किम ने उन्नीस सौ तिरानवे में फिल्म उद्योग से संन्यास ले लिया।  उनकी आखिरी फिल्में प्रतिकार हनीमून बलवान मुस्कराहट और बुलंद में अतिथि भूमिकाएं थीं
#   RTF: 0.1045
#
# [clean] data/w5Jyq3XMbb3WwiKQ.wav
# ...

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(repo_id="ARTPARK-IISc/SraVaani-1.0", filename="tokenizer.model")
# Out:
# tokenizer.model: reconstructing file:   0%|          |  0.00B /  325kB
# tokenizer.model: downloading bytes:           |  0.00B
# '/root/.cache/huggingface/hub/models--ARTPARK-IISc--SraVaani-1.0/snapshots/f5dd5358325a5208775b91dad98918e079ea2b27/tokenizer.model'

# %%
# !python sraavani.py \
  --data-dir data \
  --evaluate \
  --language hi \
  --batch-size 4 \
  --chunk-seconds 30 \
  --overlap-seconds 1.0
# Out:
# ...
#
# Loading model from local snapshot: /root/.cache/huggingface/hub/models--ARTPARK-IISc--SraVaani-1.0/snapshots/f5dd5358325a5208775b91dad98918e079ea2b27
# Loading model on cuda: ARTPARK-IISc/SraVaani-1.0
#
#
# SraVaani configuration: batch_size=4, chunk_seconds=30.0, overlap_seconds=1.0
# Device: cuda
# Pre-loading and resampling base audio samples...
# SraVaani batch: 4 chunks | durations=7.0s, 9.5s, 11.6s, 30.0s
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py:1790: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1479.)
#   return forward_call(*args, **kwargs)
# SraVaani batch: 4 chunks | durations=30.0s, 30.0s, 30.0s, 30.0s
# SraVaani batch: 4 chunks | durations=30.0s, 30.0s, 30.0s, 30.0s
# ...
